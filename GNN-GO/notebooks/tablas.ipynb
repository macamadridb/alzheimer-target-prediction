# %% [markdown]
# # Tablas infromativas

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# Out:
# ERROR! Session/line number was not unique in database. History logging moved to new session 166

# %%
# Configuración general de gráficos
sns.set(style="whitegrid")
plt.rcParams['figure.figsize'] = (10, 6)

# %%
base_output_dir = os.path.join("..", "notebooks","GNN-GO", "output")
modulos_df = os.path.join(base_output_dir, "resultados_modulos.csv")
go_df = os.path.join(base_output_dir, "proteinas_con_go_representativo.csv")

base_input_dir = os.path.join("..", "notebooks","GNN-GO", "input")
metadata_path = os.path.join(base_input_dir, "metadata_proteina.csv")


#metadata_path = "../data/Input/metadata_proteins.csv"
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# File ~\AppData\Roaming\Python\Python311\site-packages\IPython\core\async_helpers.py:129, in _pseudo_sync_runner(coro)
#     121 """
#     122 A runner that does not really allow async execution, and just advance the coroutine.
#     123
#    (...)
#     126 Credit to Nathaniel Smith
#     127 """
#     128 try:
# --> 129     coro.send(None)
#     130 except StopIteration as exc:
#     131     return exc.value
#
# File ~\AppData\Roaming\Python\Python311\site-packages\IPython\core\interactiveshell.py:3301, in InteractiveShell.run_cell_async(self, raw_cell, store_history, silent, shell_futures, transformed_cell, preprocessing_exc_tuple, cell_id)
#    3298 compiler = self.compile if shell_futures else self.compiler_class()
#    3300 with self.builtin_trap:
# -> 3301     cell_name = compiler.cache(cell, self.execution_count, raw_code=raw_cell)
#    3303     with self.display_trap:
#    3304         # Compile to bytecode
#    3305         try:
#
# File ~\AppData\Roaming\Python\Python311\site-packages\IPython\core\compilerop.py:155, in CachingCompiler.cache(self, transformed_code, number, raw_code)
#     152 if raw_code is None:
#     153     raw_code = transformed_code
# --> 155 name = self.get_code_name(raw_code, transformed_code, number)
#     157 # Save the execution count
#     158 self._filename_map[name] = number
#
# File ~\AppData\Roaming\Python\Python311\site-packages\ipykernel\compiler.py:105, in XCachingCompiler.get_code_name(self, raw_code, code, number)
#     103 def get_code_name(self, raw_code, code, number):
#     104     """Get the code name."""
# --> 105     return get_file_name(raw_code)
#
# File ~\AppData\Roaming\Python\Python311\site-packages\ipykernel\compiler.py:91, in get_file_name(code)
#      89 if cell_name is None:
#      90     name = murmur2_x86(code, get_tmp_hash_seed())
# ---> 91     cell_name = get_tmp_directory() + os.sep + str(name) + ".py"
#      92 return cell_name
#
# File ~\AppData\Roaming\Python\Python311\site-packages\ipykernel\compiler.py:76, in get_tmp_directory()
#      74 def get_tmp_directory():
#      75     """Get a temp directory."""
# ---> 76     tmp_dir = convert_to_long_pathname(tempfile.gettempdir())
#      77     pid = os.getpid()
#      78     return tmp_dir + os.sep + "ipykernel_" + str(pid)
#
# File ~\AppData\Roaming\Python\Python311\site-packages\ipykernel\compiler.py:61, in _convert_to_long_pathname(filename)
#      59 def _convert_to_long_pathname(filename):
#      60     buf = ctypes.create_unicode_buffer(MAX_PATH)
# ---> 61     rv = _GetLongPathName(filename, buf, MAX_PATH)
#      62     if rv != 0 and rv <= MAX_PATH:
#      63         filename = buf.value
#
# KeyboardInterrupt:

# %%
# --- 2. Cantidad de proteínas por módulo ---
modulos_df['num_proteins'].plot(kind='bar', color='skyblue')
plt.title("Número de proteínas por módulo")
plt.xlabel("Módulo")
plt.ylabel("Número de proteínas")
plt.xticks(rotation=90)
plt.tight_layout()
plt.show()

# %%
# --- 3. Distribución de proteínas DEG por módulo ---
# Convertir string de dict a diccionario real
import ast
modulos_df['deg_distribution'] = modulos_df['deg_distribution'].apply(ast.literal_eval)

deg_expanded = modulos_df[['module_id', 'deg_distribution']].explode('deg_distribution')
deg_rows = []
for idx, row in modulos_df.iterrows():
    for status, perc in row['deg_distribution'].items():
        deg_rows.append({'module_id': row['module_id'], 'DEG': status, 'Porcentaje': float(perc.strip('%'))})

deg_df = pd.DataFrame(deg_rows)

sns.barplot(data=deg_df, x='module_id', y='Porcentaje', hue='DEG')
plt.title("Distribución de proteínas DEG por módulo")
plt.xlabel("Módulo")
plt.ylabel("% de proteínas")
plt.xticks(rotation=90)
plt.legend(title="Estado DEG", bbox_to_anchor=(1.05, 1))
plt.tight_layout()
plt.show()

# %%
# --- 4. Distribución de Target Group por módulo ---
modulos_df['target_group_distribution'] = modulos_df['target_group_distribution'].apply(ast.literal_eval)

tg_rows = []
for idx, row in modulos_df.iterrows():
    for tg, perc in row['target_group_distribution'].items():
        tg_rows.append({'module_id': row['module_id'], 'Target_Group': tg, 'Porcentaje': float(perc.strip('%'))})

tg_df = pd.DataFrame(tg_rows)

sns.barplot(data=tg_df, x='module_id', y='Porcentaje', hue='Target_Group')
plt.title("Distribución de Target Groups por módulo")
plt.xlabel("Módulo")
plt.ylabel("% de proteínas")
plt.xticks(rotation=90)
plt.legend(title="Target Group", bbox_to_anchor=(1.05, 1))
plt.tight_layout()
plt.show()

# %%
# --- 5. GO representativos más frecuentes ---
top_go_terms = go_df['GO_term'].value_counts().head(15)

top_go_terms.plot(kind='barh', color='salmon')
plt.title("Términos GO representativos más frecuentes")
plt.xlabel("Número de proteínas")
plt.ylabel("GO_term")
plt.gca().invert_yaxis()
plt.tight_layout()
plt.show()

# %%
# matriz confusión
# Unir datos para obtener Target Group y DEG por proteína
merged_df = go_df.merge(metadata_df, on='proteina')

# Crear tabla de contingencia
conf_matrix = pd.crosstab(merged_df['Target_group'], merged_df['DEG'])

# Visualizar con heatmap
sns.heatmap(conf_matrix, annot=True, fmt='d', cmap='Blues')
plt.title("Matriz de Confusión: Target Group vs DEG")
plt.xlabel("Estado DEG")
plt.ylabel("Target Group")
plt.tight_layout()
plt.show()
